# %%
import torch
import tensorflow
CUDA_VISIBLE_DEVICES=1
torch.cuda.set_device(0)

# %%
# %run main.py --mode train --dataset RaFD --image_size 128 --c_dim 2 \
                 --sample_dir stargan_rafd/samples --log_dir stargan_rafd/logs \
                 --model_save_dir stargan_rafd/models --result_dir stargan_rafd/results

# %%
# %run main.py --mode train --dataset RaFD --image_size 128 --rafd_crop_size 128 --c_dim 2\
                 --batch_size 16\
                 --rafd_image_dir /home/rongliang/StarGAN/data/data_5000/train \
                 --sample_dir /home/rongliang/StarGAN/project/Results_181114 --log_dir /home/rongliang/StarGAN/project/logs \
                 --model_save_dir /home/rongliang/StarGAN/project/models_181114 --result_dir /home/rongliang/StarGAN/project/results
# Out:
# Namespace(attr_path='data/list_attr_celeba.txt', batch_size=16, beta1=0.5, beta2=0.999, c2_dim=8, c_dim=2, celeba_crop_size=178, celeba_image_dir='data/CelebA_nocrop/images', d_conv_dim=64, d_lr=0.0001, d_repeat_num=6, dataset='RaFD', g_conv_dim=64, g_lr=0.0001, g_repeat_num=6, image_size=128, lambda_cls=1, lambda_gp=10, lambda_rec=10, log_dir='/home/rongliang/StarGAN/project/logs', log_step=10, lr_update_step=1000, mode='train', model_save_dir='/home/rongliang/StarGAN/project/models_181114', model_save_step=10000, n_critic=5, num_iters=200000, num_iters_decay=100000, num_workers=1, rafd_crop_size=128, rafd_image_dir='/home/rongliang/StarGAN/data/data_5000/train', result_dir='/home/rongliang/StarGAN/project/results', resume_iters=None, sample_dir='/home/rongliang/StarGAN/project/Results_181114', sample_step=1000, selected_attrs=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'], test_iters=200000, use_tensorboard=True)
# Generator(
#   (main): Sequential(
# ...

# %%
# %run main.py --mode test --dataset RaFD --image_size 128 --rafd_crop_size 128 --c_dim 2 --batch_size 1 \
                 --rafd_image_dir /home/rongliang/StarGAN/data/data_5000/train \
                 --sample_dir /home/rongliang/StarGAN/project/samples_181114 --log_dir /home/rongliang/StarGAN/project/logs_test \
                 --model_save_dir /home/rongliang/StarGAN/project/models_181114 --result_dir /home/rongliang/StarGAN/project/final_181114
# Out:
# Namespace(attr_path='data/list_attr_celeba.txt', batch_size=1, beta1=0.5, beta2=0.999, c2_dim=8, c_dim=2, celeba_crop_size=178, celeba_image_dir='data/CelebA_nocrop/images', d_conv_dim=64, d_lr=0.0001, d_repeat_num=6, dataset='RaFD', g_conv_dim=64, g_lr=0.0001, g_repeat_num=6, image_size=128, lambda_cls=1, lambda_gp=10, lambda_rec=10, log_dir='/home/rongliang/StarGAN/project/logs_test', log_step=10, lr_update_step=1000, mode='test', model_save_dir='/home/rongliang/StarGAN/project/models_181114', model_save_step=10000, n_critic=5, num_iters=200000, num_iters_decay=100000, num_workers=1, rafd_crop_size=128, rafd_image_dir='/home/rongliang/StarGAN/data/data_5000/train', result_dir='/home/rongliang/StarGAN/project/final_181114', resume_iters=None, sample_dir='/home/rongliang/StarGAN/project/samples_181114', sample_step=1000, selected_attrs=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'], test_iters=200000, use_tensorboard=True)
# Generator(
#   (main): Sequential(
# ...
